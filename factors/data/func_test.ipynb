# %%
# 查看D:\wjq\working\citic\codes_wjq(1)\factors\data\akshare_cache\stock_financial_report_sina_balance_sheet下的文件数量
import os
cache_dir = "D:/wjq/working/citic/codes_wjq(1)/factors/data/akshare_cache/stock_financial_report_sina_income_statement"
file_count = len(os.listdir(cache_dir))
print(f"文件数量: {file_count}")
# Out:
# 文件数量: 553
