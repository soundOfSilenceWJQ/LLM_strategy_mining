# %%
import akshare as ak

stock_financial_abstract_df = ak.stock_financial_abstract(symbol="600004")
print(stock_financial_abstract_df)
# Out:
#       选项        指标      20260331      20251231      20250930      20250630  \
# 0   常用指标     归母净利润  1.676808e+08  1.468349e+09  1.095810e+09  7.500459e+08
# 1   常用指标     营业总收入  1.976981e+09  7.955002e+09  5.696989e+09  3.726046e+09
# 2   常用指标      营业成本  1.765264e+09  6.738620e+09  4.637197e+09  3.022619e+09
# 3   常用指标       净利润  1.850154e+08  1.513674e+09  1.123100e+09  7.697714e+08
# 4   常用指标     扣非净利润  1.660678e+08  9.587006e+08  8.553375e+08  5.618202e+08
# ..   ...       ...           ...           ...           ...           ...
# 75  营运能力    总资产周转率  6.630100e-02  2.807180e-01  2.076270e-01  1.371380e-01
# 76  营运能力   总资产周转天数  1.357430e+03  1.282422e+03  1.300406e+03  1.312546e+03
# 77  营运能力   流动资产周转率  2.003300e-01  1.013208e+00  8.050200e-01  5.608780e-01
# 78  营运能力  流动资产周转天数  4.492579e+02  3.553070e+02  3.353953e+02  3.209249e+02
# 79  营运能力   应付账款周转率  1.572385e+00  6.019882e+00  4.730507e+00  3.291041e+00
#
# ...

# %%
# 查看D:\wjq\working\citic\codes_wjq(1)\factors\data\hs300_stock_cache\stock_financial_report_sina_income_statement下文件数量
import os
file_list = os.listdir(r"D:\wjq\working\citic\codes_wjq(1)\factors\data\hs300_stock_cache\stock_financial_report_sina_cash_flow")
print(len(file_list))
# Out:
# 269

# %%
# load这个pkl文件：D:\wjq\working\citic\codes_wjq(1)\factors\factor_cache_2023_2025_4\liq_force_index_20.pkl

import pandas as pd
factor_df = pd.read_pickle(r"D:\wjq\working\citic\codes_wjq(1)\factors\factor_cache_2023_2025_4\liq_force_index_20.pkl")
factor_df
# 提取二元索引中的"instrument"，查看有多少不同的股票
instruments = factor_df.index.get_level_values("instrument").unique()
print(len(instruments))
# Out:
# 5806

# %%
instruments
# Out:
# Index(['bj430017', 'bj430047', 'bj430090', 'bj430139', 'bj430198', 'bj430300',
#        'bj430418', 'bj430425', 'bj430476', 'bj430478',
#        ...
#        'sz301656', 'sz301658', 'sz301662', 'sz301665', 'sz301667', 'sz301668',
#        'sz301678', 'sz301687', 'sz302132', 'sz399300'],
#       dtype='object', name='instrument', length=5806)
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
